# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
data = pd.read_csv(r'Data3.csv')
data.rename(columns={'Unnamed: 0':'date'}, inplace=True)
data.columns
# Out:
# Index(['date', 'theta_1', 'theta_2', 'theta_3', 'theta_4', 'theta_5',
#        'theta_6'],
#       dtype='object')

# %%
df = pd.DataFrame(data)
df.columns
# Out:
# Index(['date', 'theta_1', 'theta_2', 'theta_3', 'theta_4', 'theta_5',
#        'theta_6'],
#       dtype='object')

# %%
df2 = df.set_index('date')
df2
df2.columns
# Out:
# Index(['theta_1', 'theta_2', 'theta_3', 'theta_4', 'theta_5', 'theta_6'], dtype='object')

# %%
df2.plot()

# %%
df2.hist(bins=10)
plt.show()

# %%
df2.plot(kind='kde')
plt.show()

# %%
#x = df2.loc['Unnamed: 0']
df2.columns
df3 = pd.melt(df2, id_vars=['theta_1'], value_vars=['theta_2','theta_3'])
df3
# Out:
#        theta_1 variable     value
# 0     0.756936  theta_2 -1.467790
# 1     0.767089  theta_2  0.185797
# 2     0.404544  theta_2  1.415887
# 3     1.313957  theta_2 -1.804471
# 4     0.209862  theta_2  1.315868
# ...        ...      ...       ...
# 2185 -1.520171  theta_3  1.108275
# 2186  0.338910  theta_3  1.484579
# 2187  0.263781  theta_3 -0.112476
# 2188 -0.425098  theta_3 -0.834294
# 2189  0.848302  theta_3 -0.280626
#
# [2190 rows x 3 columns]

# %%
g = sns.FacetGrid(df3, col='variable', sharex=False)
g = g.map(plt.hist, "theta_1")

# %%
h = sns.kdeplot(df2, shade=True, color="r")

# %%
import datetime 
df2.info()
#df4=df2['2018-01-01':'2018-12-31']
df4=df2.loc['2018-01-01':'2018-12-31']
#or
#df2.loc[datetime.date(year=2018)]
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1095 entries, 2017-01-01 to 2019-12-31
# Data columns (total 6 columns):
# theta_1    1095 non-null float64
# theta_2    1095 non-null float64
# theta_3    1095 non-null float64
# theta_4    1095 non-null float64
# theta_5    1095 non-null float64
# theta_6    1095 non-null float64
# dtypes: float64(6)
# memory usage: 99.9+ KB

# %%
df4.hist(bins=5)
plt.show()
